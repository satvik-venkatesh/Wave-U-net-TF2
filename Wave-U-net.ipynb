# %% [markdown]
# <a href="https://colab.research.google.com/github/satvik-venkatesh/Wave-U-net-TF2/blob/main/Wave-U-net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Layer

# %%
def get_padding(shape, num_layers=12, filter_size=15, input_filter_size=15, output_filter_size=1, merge_filter_size=5, num_channels=1, context = True):
    '''
    Calculates the required amounts of padding along each axis of the input and output, so that the Unet works and has the given shape as output shape
    :param shape: Desired output shape 
    :return: Input_shape, output_shape, where each is a list [batch_size, time_steps, channels]
    '''

    if context:
        # Check if desired shape is possible as output shape - go from output shape towards lowest-res feature map
        rem = float(shape[1]) # Cut off batch size number and channel

        # Output filter size
        rem = rem - output_filter_size + 1

        # Upsampling blocks
        for i in range(num_layers):
            rem = rem + merge_filter_size - 1
            rem = (rem + 1.) / 2.# out = in + in - 1 <=> in = (out+1)/

        # Round resulting feature map dimensions up to nearest integer
        x = np.asarray(np.ceil(rem),dtype=np.int64)
        assert(x >= 2)

        # Compute input and output shapes based on lowest-res feature map
        output_shape = x
        input_shape = x

        # Extra conv
        input_shape = input_shape + filter_size - 1

        # Go from centre feature map through up- and downsampling blocks
        for i in range(num_layers):
            output_shape = 2*output_shape - 1 #Upsampling
            output_shape = output_shape - merge_filter_size + 1 # Conv

            input_shape = 2*input_shape - 1 # Decimation
            if i < num_layers - 1:
                input_shape = input_shape + filter_size - 1 # Conv
            else:
                input_shape = input_shape + input_filter_size - 1

        # Output filters
        output_shape = output_shape - output_filter_size + 1

        input_shape = np.concatenate([[shape[0]], [input_shape], [num_channels]])
        output_shape = np.concatenate([[shape[0]], [output_shape], [num_channels]])

        return input_shape, output_shape
    else:
        return [shape[0], shape[1], num_channels], [shape[0], shape[1], num_channels]

# %%
get_padding((16, 16389, 1))
# Out:
# (array([    16, 147443,      1]), array([   16, 16389,     1]))

# %%
class AudioClipLayer(Layer):

    def __init__(self, units=32, **kwargs):
        '''Initializes the instance attributes'''
        super(AudioClipLayer, self).__init__(**kwargs)
        self.units = units

    def build(self, input_shape):
        '''Create the state of the layer (weights)'''
        # initialize the weights
        pass
        
    def call(self, inputs, training):
        '''Defines the computation from inputs to outputs'''
        if training:
            return inputs
        else:
            return tf.maximum(tf.minimum(inputs, 1.0), -1.0)

#        return tf.matmul(inputs, self.w) + self.b

# %%
# Learned Interpolation layer

class InterpolationLayer(Layer):

    def __init__(self, padding = "valid", **kwargs):
        '''Initializes the instance attributes'''
        super(InterpolationLayer, self).__init__(**kwargs)
        self.padding = padding

    def build(self, input_shape):
        '''Create the state of the layer (weights)'''
        self.features = input_shape.as_list()[3]

        # initialize the weights
        w_init = tf.random_normal_initializer()
        self.w = tf.Variable(name="kernel",
            initial_value=w_init(shape=(self.features, ),
                                 dtype='float32'),
            trainable=True)

    def call(self, inputs):
        '''Defines the computation from inputs to outputs'''

        w_scaled = tf.math.sigmoid(self.w)

        counter_w = 1 - w_scaled

        conv_weights = tf.expand_dims(tf.concat([tf.expand_dims(tf.linalg.diag(w_scaled), axis=0), tf.expand_dims(tf.linalg.diag(counter_w), axis=0)], axis=0), axis=0)

        intermediate_vals = tf.nn.conv2d(inputs, conv_weights, strides=[1,1,1,1], padding=self.padding.upper())

        intermediate_vals = tf.transpose(intermediate_vals, [2, 0, 1, 3])
        out = tf.transpose(inputs, [2, 0, 1, 3])
        
        num_entries = out.shape.as_list()[0]
        out = tf.concat([out, intermediate_vals], axis=0)

        indices = list()

        # num_outputs = 2*num_entries - 1
        num_outputs = (2*num_entries - 1) if self.padding == "valid" else 2*num_entries

        for idx in range(num_outputs):
            if idx % 2 == 0:
                indices.append(idx // 2)
            else:
                indices.append(num_entries + idx//2)
        out = tf.gather(out, indices)
        current_layer = tf.transpose(out, [1, 2, 0, 3])

        return current_layer

# %%
class CropLayer(Layer):
    def __init__(self, x2, match_feature_dim=True, **kwargs):
        '''Initializes the instance attributes'''
        super(CropLayer, self).__init__(**kwargs)
        self.match_feature_dim = match_feature_dim
        self.x2 = x2

    def build(self, input_shape):
        '''Create the state of the layer (weights)'''
        # initialize the weights
        pass
        
    def call(self, inputs):
        '''Defines the computation from inputs to outputs'''
        if self.x2 is None:
            return inputs

        inputs = self.crop(inputs, self.x2.shape.as_list(), self.match_feature_dim)
        return inputs

    def crop(self, tensor, target_shape, match_feature_dim=True):
        '''
        Crops a 3D tensor [batch_size, width, channels] along the width axes to a target shape.
        Performs a centre crop. If the dimension difference is uneven, crop last dimensions first.
        :param tensor: 4D tensor [batch_size, width, height, channels] that should be cropped. 
        :param target_shape: Target shape (4D tensor) that the tensor should be cropped to
        :return: Cropped tensor
        '''
        shape = np.array(tensor.shape.as_list())

        ddif = shape[1] - target_shape[1]

        if (ddif % 2 != 0):
            print("WARNING: Cropping with uneven number of extra entries on one side")
        # assert diff[1] >= 0 # Only positive difference allowed
        if ddif == 0:
            return tensor
        crop_start = ddif // 2
        crop_end = ddif - crop_start

        return tensor[:,crop_start:-crop_end,:]

# %%
class IndependentOutputLayer(Layer):

    def __init__(self, source_names, num_channels, filter_width, padding="valid", **kwargs):
        '''Initializes the instance attributes'''
        super(IndependentOutputLayer, self).__init__(**kwargs)
        self.source_names = source_names
        self.num_channels = num_channels
        self.filter_width = filter_width
        self.padding = padding

        self.conv1a = tf.keras.layers.Conv1D(self.num_channels, self.filter_width, padding= self.padding)


    def build(self, input_shape):
        '''Create the state of the layer (weights)'''
        pass
        
    def call(self, inputs, training):
        '''Defines the computation from inputs to outputs'''
        outputs = {}
        for name in self.source_names:
            out = self.conv1a(inputs)
            outputs[name] = out
        
        return outputs

# %%
class DiffOutputLayer(Layer):

    def __init__(self, source_names, num_channels, filter_width, padding="valid", **kwargs):
        '''Initializes the instance attributes'''
        super(DiffOutputLayer, self).__init__(**kwargs)
        self.source_names = source_names
        self.num_channels = num_channels
        self.filter_width = filter_width
        self.padding = padding

        self.conv1a = tf.keras.layers.Conv1D(self.num_channels, self.filter_width, padding= self.padding)


    def build(self, input_shape):
        '''Create the state of the layer (weights)'''
        pass
        
    def call(self, inputs, training):
        '''Defines the computation from inputs to outputs'''
        outputs = {}
        sum_source = 0
        for name in self.source_names[:-1]:
            out = self.conv1a(inputs[0])
            out = AudioClipLayer()(out)
            outputs[name] = out
            sum_source = sum_source + out
        
        last_source = CropLayer(sum_source)(inputs[1]) - sum_source
        last_source = AudioClipLayer()(last_source)

        outputs[self.source_names[-1]] = last_source

        return outputs

# %%
def wave_u_net():
  num_initial_filters = 24
  num_layers = 12
  kernel_size = 15
  merge_filter_size = 5
  source_names = ["bass", "drums", "other", "vocals"]
  num_channels = 1
  output_filter_size = 1
  padding = "same"
  input_size = 16384 * 4
  context = False
  upsampling_type = "learned"     # "learned" or "linear"
  output_activation = "linear"    # "linear" or "tanh"
  output_type = "difference"          # "direct" or "difference" 

  # `enc_outputs` stores the downsampled outputs to re-use during upsampling.
  enc_outputs = []

  # `raw_input` is the input to the network
  raw_input = tf.keras.layers.Input(shape=(input_size, 1),name="raw_input")
  X = raw_input
  inp = raw_input

  # Down sampling
  for i in range(num_layers):
    X = tf.keras.layers.Conv1D(filters=num_initial_filters + (num_initial_filters * i),
                          kernel_size=kernel_size,strides=1,
                          padding=padding, name="Down_Conv_"+str(i))(X)
    X = tf.keras.layers.LeakyReLU(name="Down_Conv_Activ_"+str(i))(X)

    enc_outputs.append(X)

    X = tf.keras.layers.Lambda(lambda x: x[:,::2,:], name="Decimate_"+str(i))(X)


  X = tf.keras.layers.Conv1D(filters=num_initial_filters + (num_initial_filters * num_layers),
                          kernel_size=kernel_size,strides=1,
                          padding=padding, name="Down_Conv_"+str(num_layers))(X)
  X = tf.keras.layers.LeakyReLU(name="Down_Conv_Activ_"+str(num_layers))(X)



  # Up sampling
  for i in range(num_layers):
    X = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1), name="exp_dims_"+str(i))(X)
    
    if upsampling_type == "learned":
      X = InterpolationLayer(name="IntPol_"+str(i), padding=padding)(X)

    else:
      if context:
        X = tf.keras.layers.Lambda(lambda x: tf.image.resize(x, [1, x.shape.as_list()[2] * 2 - 1]), name="bilinear_interpol_"+str(i))(X)
        # current_layer = tf.image.resize_bilinear(current_layer, [1, current_layer.get_shape().as_list()[2] * 2 - 1], align_corners=True)
      else:
        X = tf.keras.layers.Lambda(lambda x: tf.image.resize(x, [1, x.shape.as_list()[2] * 2]), name="bilinear_interpol_"+str(i))(X)
        # current_layer = tf.image.resize_bilinear(current_layer, [1, current_layer.get_shape().as_list()[2]*2]) # out = in + in - 1


    X = tf.keras.layers.Lambda(lambda x: tf.squeeze(x, axis=1), name="sq_dims_"+str(i))(X)
    
    c_layer = CropLayer(X, False, name="crop_layer_"+str(i))(enc_outputs[-i-1])
    X = tf.keras.layers.Concatenate(axis=2, name="concatenate_"+str(i))([X, c_layer]) 


    X = tf.keras.layers.Conv1D(filters=num_initial_filters + (num_initial_filters * (num_layers - i - 1)),
                            kernel_size=merge_filter_size,strides=1,
                            padding=padding, name="Up_Conv_"+str(i))(X)
    X = tf.keras.layers.LeakyReLU(name="Up_Conv_Activ_"+str(i))(X)


  c_layer = CropLayer(X, False, name="crop_layer_"+str(num_layers))(inp)
  X = tf.keras.layers.Concatenate(axis=2, name="concatenate_"+str(num_layers))([X, c_layer]) 
  X = AudioClipLayer(name="audio_clip_"+str(0))(X)

  if output_type == "direct":
    X = IndependentOutputLayer(source_names, num_channels, output_filter_size, padding=padding, name="independent_out")(X)

  else:
    # Difference Output
    cropped_input = CropLayer(X, False, name="crop_layer_"+str(num_layers+1))(inp)
    X = DiffOutputLayer(source_names, num_channels, output_filter_size, padding=padding, name="diff_out")([X, cropped_input])

  o = X
  model = tf.keras.Model(inputs=raw_input, outputs=o)
  return model

# %%
m = wave_u_net()

# %%
m.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# raw_input (InputLayer)          [(None, 65536, 1)]   0
# __________________________________________________________________________________________________
# Down_Conv_0 (Conv1D)            (None, 65536, 24)    384         raw_input[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_0 (LeakyReLU)   (None, 65536, 24)    0           Down_Conv_0[0][0]
# __________________________________________________________________________________________________
# Decimate_0 (Lambda)             (None, 32768, 24)    0           Down_Conv_Activ_0[0][0]
# __________________________________________________________________________________________________
# Down_Conv_1 (Conv1D)            (None, 32768, 48)    17328       Decimate_0[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_1 (LeakyReLU)   (None, 32768, 48)    0           Down_Conv_1[0][0]
# __________________________________________________________________________________________________
# Decimate_1 (Lambda)             (None, 16384, 48)    0           Down_Conv_Activ_1[0][0]
# __________________________________________________________________________________________________
# Down_Conv_2 (Conv1D)            (None, 16384, 72)    51912       Decimate_1[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_2 (LeakyReLU)   (None, 16384, 72)    0           Down_Conv_2[0][0]
# __________________________________________________________________________________________________
# Decimate_2 (Lambda)             (None, 8192, 72)     0           Down_Conv_Activ_2[0][0]
# __________________________________________________________________________________________________
# Down_Conv_3 (Conv1D)            (None, 8192, 96)     103776      Decimate_2[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_3 (LeakyReLU)   (None, 8192, 96)     0           Down_Conv_3[0][0]
# __________________________________________________________________________________________________
# Decimate_3 (Lambda)             (None, 4096, 96)     0           Down_Conv_Activ_3[0][0]
# __________________________________________________________________________________________________
# Down_Conv_4 (Conv1D)            (None, 4096, 120)    172920      Decimate_3[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_4 (LeakyReLU)   (None, 4096, 120)    0           Down_Conv_4[0][0]
# __________________________________________________________________________________________________
# Decimate_4 (Lambda)             (None, 2048, 120)    0           Down_Conv_Activ_4[0][0]
# __________________________________________________________________________________________________
# Down_Conv_5 (Conv1D)            (None, 2048, 144)    259344      Decimate_4[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_5 (LeakyReLU)   (None, 2048, 144)    0           Down_Conv_5[0][0]
# __________________________________________________________________________________________________
# Decimate_5 (Lambda)             (None, 1024, 144)    0           Down_Conv_Activ_5[0][0]
# __________________________________________________________________________________________________
# Down_Conv_6 (Conv1D)            (None, 1024, 168)    363048      Decimate_5[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_6 (LeakyReLU)   (None, 1024, 168)    0           Down_Conv_6[0][0]
# __________________________________________________________________________________________________
# Decimate_6 (Lambda)             (None, 512, 168)     0           Down_Conv_Activ_6[0][0]
# __________________________________________________________________________________________________
# Down_Conv_7 (Conv1D)            (None, 512, 192)     484032      Decimate_6[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_7 (LeakyReLU)   (None, 512, 192)     0           Down_Conv_7[0][0]
# __________________________________________________________________________________________________
# Decimate_7 (Lambda)             (None, 256, 192)     0           Down_Conv_Activ_7[0][0]
# __________________________________________________________________________________________________
# Down_Conv_8 (Conv1D)            (None, 256, 216)     622296      Decimate_7[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_8 (LeakyReLU)   (None, 256, 216)     0           Down_Conv_8[0][0]
# __________________________________________________________________________________________________
# Decimate_8 (Lambda)             (None, 128, 216)     0           Down_Conv_Activ_8[0][0]
# __________________________________________________________________________________________________
# Down_Conv_9 (Conv1D)            (None, 128, 240)     777840      Decimate_8[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_9 (LeakyReLU)   (None, 128, 240)     0           Down_Conv_9[0][0]
# __________________________________________________________________________________________________
# Decimate_9 (Lambda)             (None, 64, 240)      0           Down_Conv_Activ_9[0][0]
# __________________________________________________________________________________________________
# Down_Conv_10 (Conv1D)           (None, 64, 264)      950664      Decimate_9[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_10 (LeakyReLU)  (None, 64, 264)      0           Down_Conv_10[0][0]
# __________________________________________________________________________________________________
# Decimate_10 (Lambda)            (None, 32, 264)      0           Down_Conv_Activ_10[0][0]
# __________________________________________________________________________________________________
# Down_Conv_11 (Conv1D)           (None, 32, 288)      1140768     Decimate_10[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_11 (LeakyReLU)  (None, 32, 288)      0           Down_Conv_11[0][0]
# __________________________________________________________________________________________________
# Decimate_11 (Lambda)            (None, 16, 288)      0           Down_Conv_Activ_11[0][0]
# __________________________________________________________________________________________________
# Down_Conv_12 (Conv1D)           (None, 16, 312)      1348152     Decimate_11[0][0]
# __________________________________________________________________________________________________
# Down_Conv_Activ_12 (LeakyReLU)  (None, 16, 312)      0           Down_Conv_12[0][0]
# __________________________________________________________________________________________________
# exp_dims_0 (Lambda)             (None, 1, 16, 312)   0           Down_Conv_Activ_12[0][0]
# __________________________________________________________________________________________________
# IntPol_0 (InterpolationLayer)   (None, 1, 32, 312)   312         exp_dims_0[0][0]
# __________________________________________________________________________________________________
# sq_dims_0 (Lambda)              (None, 32, 312)      0           IntPol_0[0][0]
# __________________________________________________________________________________________________
# crop_layer_0 (CropLayer)        (None, 32, 288)      0           Down_Conv_Activ_11[0][0]
# __________________________________________________________________________________________________
# concatenate_0 (Concatenate)     (None, 32, 600)      0           sq_dims_0[0][0]
#                                                                  crop_layer_0[0][0]
# __________________________________________________________________________________________________
# Up_Conv_0 (Conv1D)              (None, 32, 288)      864288      concatenate_0[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_0 (LeakyReLU)     (None, 32, 288)      0           Up_Conv_0[0][0]
# __________________________________________________________________________________________________
# exp_dims_1 (Lambda)             (None, 1, 32, 288)   0           Up_Conv_Activ_0[0][0]
# __________________________________________________________________________________________________
# IntPol_1 (InterpolationLayer)   (None, 1, 64, 288)   288         exp_dims_1[0][0]
# __________________________________________________________________________________________________
# sq_dims_1 (Lambda)              (None, 64, 288)      0           IntPol_1[0][0]
# __________________________________________________________________________________________________
# crop_layer_1 (CropLayer)        (None, 64, 264)      0           Down_Conv_Activ_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 552)      0           sq_dims_1[0][0]
#                                                                  crop_layer_1[0][0]
# __________________________________________________________________________________________________
# Up_Conv_1 (Conv1D)              (None, 64, 264)      728904      concatenate_1[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_1 (LeakyReLU)     (None, 64, 264)      0           Up_Conv_1[0][0]
# __________________________________________________________________________________________________
# exp_dims_2 (Lambda)             (None, 1, 64, 264)   0           Up_Conv_Activ_1[0][0]
# __________________________________________________________________________________________________
# IntPol_2 (InterpolationLayer)   (None, 1, 128, 264)  264         exp_dims_2[0][0]
# __________________________________________________________________________________________________
# sq_dims_2 (Lambda)              (None, 128, 264)     0           IntPol_2[0][0]
# __________________________________________________________________________________________________
# crop_layer_2 (CropLayer)        (None, 128, 240)     0           Down_Conv_Activ_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 504)     0           sq_dims_2[0][0]
#                                                                  crop_layer_2[0][0]
# __________________________________________________________________________________________________
# Up_Conv_2 (Conv1D)              (None, 128, 240)     605040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_2 (LeakyReLU)     (None, 128, 240)     0           Up_Conv_2[0][0]
# __________________________________________________________________________________________________
# exp_dims_3 (Lambda)             (None, 1, 128, 240)  0           Up_Conv_Activ_2[0][0]
# __________________________________________________________________________________________________
# IntPol_3 (InterpolationLayer)   (None, 1, 256, 240)  240         exp_dims_3[0][0]
# __________________________________________________________________________________________________
# sq_dims_3 (Lambda)              (None, 256, 240)     0           IntPol_3[0][0]
# __________________________________________________________________________________________________
# crop_layer_3 (CropLayer)        (None, 256, 216)     0           Down_Conv_Activ_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 456)     0           sq_dims_3[0][0]
#                                                                  crop_layer_3[0][0]
# __________________________________________________________________________________________________
# Up_Conv_3 (Conv1D)              (None, 256, 216)     492696      concatenate_3[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_3 (LeakyReLU)     (None, 256, 216)     0           Up_Conv_3[0][0]
# __________________________________________________________________________________________________
# exp_dims_4 (Lambda)             (None, 1, 256, 216)  0           Up_Conv_Activ_3[0][0]
# __________________________________________________________________________________________________
# IntPol_4 (InterpolationLayer)   (None, 1, 512, 216)  216         exp_dims_4[0][0]
# __________________________________________________________________________________________________
# sq_dims_4 (Lambda)              (None, 512, 216)     0           IntPol_4[0][0]
# __________________________________________________________________________________________________
# crop_layer_4 (CropLayer)        (None, 512, 192)     0           Down_Conv_Activ_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512, 408)     0           sq_dims_4[0][0]
#                                                                  crop_layer_4[0][0]
# __________________________________________________________________________________________________
# Up_Conv_4 (Conv1D)              (None, 512, 192)     391872      concatenate_4[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_4 (LeakyReLU)     (None, 512, 192)     0           Up_Conv_4[0][0]
# __________________________________________________________________________________________________
# exp_dims_5 (Lambda)             (None, 1, 512, 192)  0           Up_Conv_Activ_4[0][0]
# __________________________________________________________________________________________________
# IntPol_5 (InterpolationLayer)   (None, 1, 1024, 192) 192         exp_dims_5[0][0]
# __________________________________________________________________________________________________
# sq_dims_5 (Lambda)              (None, 1024, 192)    0           IntPol_5[0][0]
# __________________________________________________________________________________________________
# crop_layer_5 (CropLayer)        (None, 1024, 168)    0           Down_Conv_Activ_6[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 1024, 360)    0           sq_dims_5[0][0]
#                                                                  crop_layer_5[0][0]
# __________________________________________________________________________________________________
# Up_Conv_5 (Conv1D)              (None, 1024, 168)    302568      concatenate_5[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_5 (LeakyReLU)     (None, 1024, 168)    0           Up_Conv_5[0][0]
# __________________________________________________________________________________________________
# exp_dims_6 (Lambda)             (None, 1, 1024, 168) 0           Up_Conv_Activ_5[0][0]
# __________________________________________________________________________________________________
# IntPol_6 (InterpolationLayer)   (None, 1, 2048, 168) 168         exp_dims_6[0][0]
# __________________________________________________________________________________________________
# sq_dims_6 (Lambda)              (None, 2048, 168)    0           IntPol_6[0][0]
# __________________________________________________________________________________________________
# crop_layer_6 (CropLayer)        (None, 2048, 144)    0           Down_Conv_Activ_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 2048, 312)    0           sq_dims_6[0][0]
#                                                                  crop_layer_6[0][0]
# __________________________________________________________________________________________________
# Up_Conv_6 (Conv1D)              (None, 2048, 144)    224784      concatenate_6[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_6 (LeakyReLU)     (None, 2048, 144)    0           Up_Conv_6[0][0]
# __________________________________________________________________________________________________
# exp_dims_7 (Lambda)             (None, 1, 2048, 144) 0           Up_Conv_Activ_6[0][0]
# __________________________________________________________________________________________________
# IntPol_7 (InterpolationLayer)   (None, 1, 4096, 144) 144         exp_dims_7[0][0]
# __________________________________________________________________________________________________
# sq_dims_7 (Lambda)              (None, 4096, 144)    0           IntPol_7[0][0]
# __________________________________________________________________________________________________
# crop_layer_7 (CropLayer)        (None, 4096, 120)    0           Down_Conv_Activ_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 4096, 264)    0           sq_dims_7[0][0]
#                                                                  crop_layer_7[0][0]
# __________________________________________________________________________________________________
# Up_Conv_7 (Conv1D)              (None, 4096, 120)    158520      concatenate_7[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_7 (LeakyReLU)     (None, 4096, 120)    0           Up_Conv_7[0][0]
# __________________________________________________________________________________________________
# exp_dims_8 (Lambda)             (None, 1, 4096, 120) 0           Up_Conv_Activ_7[0][0]
# __________________________________________________________________________________________________
# IntPol_8 (InterpolationLayer)   (None, 1, 8192, 120) 120         exp_dims_8[0][0]
# __________________________________________________________________________________________________
# sq_dims_8 (Lambda)              (None, 8192, 120)    0           IntPol_8[0][0]
# __________________________________________________________________________________________________
# crop_layer_8 (CropLayer)        (None, 8192, 96)     0           Down_Conv_Activ_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 8192, 216)    0           sq_dims_8[0][0]
#                                                                  crop_layer_8[0][0]
# __________________________________________________________________________________________________
# Up_Conv_8 (Conv1D)              (None, 8192, 96)     103776      concatenate_8[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_8 (LeakyReLU)     (None, 8192, 96)     0           Up_Conv_8[0][0]
# __________________________________________________________________________________________________
# exp_dims_9 (Lambda)             (None, 1, 8192, 96)  0           Up_Conv_Activ_8[0][0]
# __________________________________________________________________________________________________
# IntPol_9 (InterpolationLayer)   (None, 1, 16384, 96) 96          exp_dims_9[0][0]
# __________________________________________________________________________________________________
# sq_dims_9 (Lambda)              (None, 16384, 96)    0           IntPol_9[0][0]
# __________________________________________________________________________________________________
# crop_layer_9 (CropLayer)        (None, 16384, 72)    0           Down_Conv_Activ_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16384, 168)   0           sq_dims_9[0][0]
#                                                                  crop_layer_9[0][0]
# __________________________________________________________________________________________________
# Up_Conv_9 (Conv1D)              (None, 16384, 72)    60552       concatenate_9[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_9 (LeakyReLU)     (None, 16384, 72)    0           Up_Conv_9[0][0]
# __________________________________________________________________________________________________
# exp_dims_10 (Lambda)            (None, 1, 16384, 72) 0           Up_Conv_Activ_9[0][0]
# __________________________________________________________________________________________________
# IntPol_10 (InterpolationLayer)  (None, 1, 32768, 72) 72          exp_dims_10[0][0]
# __________________________________________________________________________________________________
# sq_dims_10 (Lambda)             (None, 32768, 72)    0           IntPol_10[0][0]
# __________________________________________________________________________________________________
# crop_layer_10 (CropLayer)       (None, 32768, 48)    0           Down_Conv_Activ_1[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32768, 120)   0           sq_dims_10[0][0]
#                                                                  crop_layer_10[0][0]
# __________________________________________________________________________________________________
# Up_Conv_10 (Conv1D)             (None, 32768, 48)    28848       concatenate_10[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_10 (LeakyReLU)    (None, 32768, 48)    0           Up_Conv_10[0][0]
# __________________________________________________________________________________________________
# exp_dims_11 (Lambda)            (None, 1, 32768, 48) 0           Up_Conv_Activ_10[0][0]
# __________________________________________________________________________________________________
# IntPol_11 (InterpolationLayer)  (None, 1, 65536, 48) 48          exp_dims_11[0][0]
# __________________________________________________________________________________________________
# sq_dims_11 (Lambda)             (None, 65536, 48)    0           IntPol_11[0][0]
# __________________________________________________________________________________________________
# crop_layer_11 (CropLayer)       (None, 65536, 24)    0           Down_Conv_Activ_0[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 65536, 72)    0           sq_dims_11[0][0]
#                                                                  crop_layer_11[0][0]
# __________________________________________________________________________________________________
# Up_Conv_11 (Conv1D)             (None, 65536, 24)    8664        concatenate_11[0][0]
# __________________________________________________________________________________________________
# Up_Conv_Activ_11 (LeakyReLU)    (None, 65536, 24)    0           Up_Conv_11[0][0]
# __________________________________________________________________________________________________
# crop_layer_12 (CropLayer)       (None, 65536, 1)     0           raw_input[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 65536, 25)    0           Up_Conv_Activ_11[0][0]
#                                                                  crop_layer_12[0][0]
# __________________________________________________________________________________________________
# audio_clip_0 (AudioClipLayer)   (None, 65536, 25)    0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# crop_layer_13 (CropLayer)       (None, 65536, 1)     0           raw_input[0][0]
# __________________________________________________________________________________________________
# diff_out (DiffOutputLayer)      {'bass': (None, 6553 26          audio_clip_0[0][0]
#                                                                  crop_layer_13[0][0]
# ==================================================================================================
# Total params: 10,265,162
# Trainable params: 10,265,162
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
m.output
# Out:
# {'bass': <KerasTensor: shape=(None, 65536, 1) dtype=float32 (created by layer 'diff_out')>,
#  'drums': <KerasTensor: shape=(None, 65536, 1) dtype=float32 (created by layer 'diff_out')>,
#  'other': <KerasTensor: shape=(None, 65536, 1) dtype=float32 (created by layer 'diff_out')>,
#  'vocals': <KerasTensor: shape=(None, 65536, 1) dtype=float32 (created by layer 'diff_out')>}

# %%
"""
Code for Wave U-Net
"""

# ======= Config values =========
num_initial_filters = 24
num_layers = 12
kernel_size = 15
merge_filter_size = 5
source_names = ["bass", "drums", "other", "vocals"]
num_channels = 1
output_filter_size = 1



enc_outputs = []


raw_input = tf.keras.layers.Input(shape=(147443, 1),name="raw_input")
X = raw_input
inp = raw_input

# Down sampling
for i in range(num_layers):
  X = tf.keras.layers.Conv1D(filters=num_initial_filters + (num_initial_filters * i),
                         kernel_size=kernel_size,strides=1,
                         padding='valid', name="Down_Conv_"+str(i))(X)
  X = tf.keras.layers.LeakyReLU(name="DC_Act_"+str(i))(X)

  enc_outputs.append(X)

  X = tf.keras.layers.Lambda(lambda x: x[:,::2,:], name="Decimate_"+str(i))(X)


X = tf.keras.layers.Conv1D(filters=num_initial_filters + (num_initial_filters * num_layers),
                        kernel_size=kernel_size,strides=1,
                        padding='valid', name="Down_Conv_"+str(num_layers))(X)
X = tf.keras.layers.LeakyReLU(name="DC_Act_"+str(num_layers))(X)



# Up sampling
for i in range(num_layers):
  X = tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=1), name="exp_dims_"+str(i))(X)

  X = InterpolationLayer(name="IntPol_"+str(i))(X)

  X = tf.keras.layers.Lambda(lambda x: tf.squeeze(x, axis=1), name="sq_dims_"+str(i))(X)
  
  c_layer = CropLayer(X, False, name="crop_layer_"+str(i))(enc_outputs[-i-1])
  X = tf.keras.layers.Concatenate(axis=2, name="concatenate_"+str(i))([X, c_layer]) 


  X = tf.keras.layers.Conv1D(filters=num_initial_filters + (num_initial_filters * (num_layers - i - 1)),
                          kernel_size=merge_filter_size,strides=1,
                          padding='valid', name="Up_Conv_"+str(i))(X)
  X = tf.keras.layers.LeakyReLU(name="UC_Act_"+str(i))(X)


c_layer = CropLayer(X, False, name="crop_layer_"+str(num_layers))(inp)
X = tf.keras.layers.Concatenate(axis=2, name="concatenate_"+str(num_layers))([X, c_layer]) 
X = AudioClipLayer(name="audio_clip_"+str(0))(X)


# Difference Output
cropped_input = CropLayer(X, False, name="crop_layer_"+str(num_layers+1))(inp)
X = DiffOutputLayer(source_names, num_channels, output_filter_size, name="diff_out")([X, cropped_input])

o = X
model = tf.keras.Model(inputs=raw_input, outputs=o)
model.summary()
# Out:
# last_source: Tensor("diff_out/audio_clip_layer_3/Maximum:0", shape=(None, 16389, 1), dtype=float32)
# Reached here!!!
# {'bass': <tf.Tensor 'diff_out/audio_clip_layer/Maximum:0' shape=(None, 16389, 1) dtype=float32>, 'drums': <tf.Tensor 'diff_out/audio_clip_layer_1/Maximum:0' shape=(None, 16389, 1) dtype=float32>, 'other': <tf.Tensor 'diff_out/audio_clip_layer_2/Maximum:0' shape=(None, 16389, 1) dtype=float32>, 'vocals': <tf.Tensor 'diff_out/audio_clip_layer_3/Maximum:0' shape=(None, 16389, 1) dtype=float32>}
# Model: "model_24"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# raw_input (InputLayer)          [(None, 147443, 1)]  0
# __________________________________________________________________________________________________
# Down_Conv_0 (Conv1D)            (None, 147429, 24)   384         raw_input[0][0]
# __________________________________________________________________________________________________
# DC_Act_0 (LeakyReLU)            (None, 147429, 24)   0           Down_Conv_0[0][0]
# __________________________________________________________________________________________________
# Decimate_0 (Lambda)             (None, 73715, 24)    0           DC_Act_0[0][0]
# __________________________________________________________________________________________________
# Down_Conv_1 (Conv1D)            (None, 73701, 48)    17328       Decimate_0[0][0]
# __________________________________________________________________________________________________
# DC_Act_1 (LeakyReLU)            (None, 73701, 48)    0           Down_Conv_1[0][0]
# __________________________________________________________________________________________________
# Decimate_1 (Lambda)             (None, 36851, 48)    0           DC_Act_1[0][0]
# __________________________________________________________________________________________________
# Down_Conv_2 (Conv1D)            (None, 36837, 72)    51912       Decimate_1[0][0]
# __________________________________________________________________________________________________
# DC_Act_2 (LeakyReLU)            (None, 36837, 72)    0           Down_Conv_2[0][0]
# __________________________________________________________________________________________________
# Decimate_2 (Lambda)             (None, 18419, 72)    0           DC_Act_2[0][0]
# __________________________________________________________________________________________________
# Down_Conv_3 (Conv1D)            (None, 18405, 96)    103776      Decimate_2[0][0]
# __________________________________________________________________________________________________
# DC_Act_3 (LeakyReLU)            (None, 18405, 96)    0           Down_Conv_3[0][0]
# __________________________________________________________________________________________________
# Decimate_3 (Lambda)             (None, 9203, 96)     0           DC_Act_3[0][0]
# __________________________________________________________________________________________________
# Down_Conv_4 (Conv1D)            (None, 9189, 120)    172920      Decimate_3[0][0]
# __________________________________________________________________________________________________
# DC_Act_4 (LeakyReLU)            (None, 9189, 120)    0           Down_Conv_4[0][0]
# __________________________________________________________________________________________________
# Decimate_4 (Lambda)             (None, 4595, 120)    0           DC_Act_4[0][0]
# __________________________________________________________________________________________________
# Down_Conv_5 (Conv1D)            (None, 4581, 144)    259344      Decimate_4[0][0]
# __________________________________________________________________________________________________
# DC_Act_5 (LeakyReLU)            (None, 4581, 144)    0           Down_Conv_5[0][0]
# __________________________________________________________________________________________________
# Decimate_5 (Lambda)             (None, 2291, 144)    0           DC_Act_5[0][0]
# __________________________________________________________________________________________________
# Down_Conv_6 (Conv1D)            (None, 2277, 168)    363048      Decimate_5[0][0]
# __________________________________________________________________________________________________
# DC_Act_6 (LeakyReLU)            (None, 2277, 168)    0           Down_Conv_6[0][0]
# __________________________________________________________________________________________________
# Decimate_6 (Lambda)             (None, 1139, 168)    0           DC_Act_6[0][0]
# __________________________________________________________________________________________________
# Down_Conv_7 (Conv1D)            (None, 1125, 192)    484032      Decimate_6[0][0]
# __________________________________________________________________________________________________
# DC_Act_7 (LeakyReLU)            (None, 1125, 192)    0           Down_Conv_7[0][0]
# __________________________________________________________________________________________________
# Decimate_7 (Lambda)             (None, 563, 192)     0           DC_Act_7[0][0]
# __________________________________________________________________________________________________
# Down_Conv_8 (Conv1D)            (None, 549, 216)     622296      Decimate_7[0][0]
# __________________________________________________________________________________________________
# DC_Act_8 (LeakyReLU)            (None, 549, 216)     0           Down_Conv_8[0][0]
# __________________________________________________________________________________________________
# Decimate_8 (Lambda)             (None, 275, 216)     0           DC_Act_8[0][0]
# __________________________________________________________________________________________________
# Down_Conv_9 (Conv1D)            (None, 261, 240)     777840      Decimate_8[0][0]
# __________________________________________________________________________________________________
# DC_Act_9 (LeakyReLU)            (None, 261, 240)     0           Down_Conv_9[0][0]
# __________________________________________________________________________________________________
# Decimate_9 (Lambda)             (None, 131, 240)     0           DC_Act_9[0][0]
# __________________________________________________________________________________________________
# Down_Conv_10 (Conv1D)           (None, 117, 264)     950664      Decimate_9[0][0]
# __________________________________________________________________________________________________
# DC_Act_10 (LeakyReLU)           (None, 117, 264)     0           Down_Conv_10[0][0]
# __________________________________________________________________________________________________
# Decimate_10 (Lambda)            (None, 59, 264)      0           DC_Act_10[0][0]
# __________________________________________________________________________________________________
# Down_Conv_11 (Conv1D)           (None, 45, 288)      1140768     Decimate_10[0][0]
# __________________________________________________________________________________________________
# DC_Act_11 (LeakyReLU)           (None, 45, 288)      0           Down_Conv_11[0][0]
# __________________________________________________________________________________________________
# Decimate_11 (Lambda)            (None, 23, 288)      0           DC_Act_11[0][0]
# __________________________________________________________________________________________________
# Down_Conv_12 (Conv1D)           (None, 9, 312)       1348152     Decimate_11[0][0]
# __________________________________________________________________________________________________
# DC_Act_12 (LeakyReLU)           (None, 9, 312)       0           Down_Conv_12[0][0]
# __________________________________________________________________________________________________
# exp_dims_0 (Lambda)             (None, 1, 9, 312)    0           DC_Act_12[0][0]
# __________________________________________________________________________________________________
# IntPol_0 (InterpolationLayer)   (None, 1, 17, 312)   312         exp_dims_0[0][0]
# __________________________________________________________________________________________________
# sq_dims_0 (Lambda)              (None, 17, 312)      0           IntPol_0[0][0]
# __________________________________________________________________________________________________
# crop_layer_0 (CropLayer)        (None, 17, 288)      0           DC_Act_11[0][0]
# __________________________________________________________________________________________________
# concatenate_0 (Concatenate)     (None, 17, 600)      0           sq_dims_0[0][0]
#                                                                  crop_layer_0[0][0]
# __________________________________________________________________________________________________
# Up_Conv_0 (Conv1D)              (None, 13, 288)      864288      concatenate_0[0][0]
# __________________________________________________________________________________________________
# UC_Act_0 (LeakyReLU)            (None, 13, 288)      0           Up_Conv_0[0][0]
# __________________________________________________________________________________________________
# exp_dims_1 (Lambda)             (None, 1, 13, 288)   0           UC_Act_0[0][0]
# __________________________________________________________________________________________________
# IntPol_1 (InterpolationLayer)   (None, 1, 25, 288)   288         exp_dims_1[0][0]
# __________________________________________________________________________________________________
# sq_dims_1 (Lambda)              (None, 25, 288)      0           IntPol_1[0][0]
# __________________________________________________________________________________________________
# crop_layer_1 (CropLayer)        (None, 25, 264)      0           DC_Act_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 25, 552)      0           sq_dims_1[0][0]
#                                                                  crop_layer_1[0][0]
# __________________________________________________________________________________________________
# Up_Conv_1 (Conv1D)              (None, 21, 264)      728904      concatenate_1[0][0]
# __________________________________________________________________________________________________
# UC_Act_1 (LeakyReLU)            (None, 21, 264)      0           Up_Conv_1[0][0]
# __________________________________________________________________________________________________
# exp_dims_2 (Lambda)             (None, 1, 21, 264)   0           UC_Act_1[0][0]
# __________________________________________________________________________________________________
# IntPol_2 (InterpolationLayer)   (None, 1, 41, 264)   264         exp_dims_2[0][0]
# __________________________________________________________________________________________________
# sq_dims_2 (Lambda)              (None, 41, 264)      0           IntPol_2[0][0]
# __________________________________________________________________________________________________
# crop_layer_2 (CropLayer)        (None, 41, 240)      0           DC_Act_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 41, 504)      0           sq_dims_2[0][0]
#                                                                  crop_layer_2[0][0]
# __________________________________________________________________________________________________
# Up_Conv_2 (Conv1D)              (None, 37, 240)      605040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# UC_Act_2 (LeakyReLU)            (None, 37, 240)      0           Up_Conv_2[0][0]
# __________________________________________________________________________________________________
# exp_dims_3 (Lambda)             (None, 1, 37, 240)   0           UC_Act_2[0][0]
# __________________________________________________________________________________________________
# IntPol_3 (InterpolationLayer)   (None, 1, 73, 240)   240         exp_dims_3[0][0]
# __________________________________________________________________________________________________
# sq_dims_3 (Lambda)              (None, 73, 240)      0           IntPol_3[0][0]
# __________________________________________________________________________________________________
# crop_layer_3 (CropLayer)        (None, 73, 216)      0           DC_Act_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 73, 456)      0           sq_dims_3[0][0]
#                                                                  crop_layer_3[0][0]
# __________________________________________________________________________________________________
# Up_Conv_3 (Conv1D)              (None, 69, 216)      492696      concatenate_3[0][0]
# __________________________________________________________________________________________________
# UC_Act_3 (LeakyReLU)            (None, 69, 216)      0           Up_Conv_3[0][0]
# __________________________________________________________________________________________________
# exp_dims_4 (Lambda)             (None, 1, 69, 216)   0           UC_Act_3[0][0]
# __________________________________________________________________________________________________
# IntPol_4 (InterpolationLayer)   (None, 1, 137, 216)  216         exp_dims_4[0][0]
# __________________________________________________________________________________________________
# sq_dims_4 (Lambda)              (None, 137, 216)     0           IntPol_4[0][0]
# __________________________________________________________________________________________________
# crop_layer_4 (CropLayer)        (None, 137, 192)     0           DC_Act_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 137, 408)     0           sq_dims_4[0][0]
#                                                                  crop_layer_4[0][0]
# __________________________________________________________________________________________________
# Up_Conv_4 (Conv1D)              (None, 133, 192)     391872      concatenate_4[0][0]
# __________________________________________________________________________________________________
# UC_Act_4 (LeakyReLU)            (None, 133, 192)     0           Up_Conv_4[0][0]
# __________________________________________________________________________________________________
# exp_dims_5 (Lambda)             (None, 1, 133, 192)  0           UC_Act_4[0][0]
# __________________________________________________________________________________________________
# IntPol_5 (InterpolationLayer)   (None, 1, 265, 192)  192         exp_dims_5[0][0]
# __________________________________________________________________________________________________
# sq_dims_5 (Lambda)              (None, 265, 192)     0           IntPol_5[0][0]
# __________________________________________________________________________________________________
# crop_layer_5 (CropLayer)        (None, 265, 168)     0           DC_Act_6[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 265, 360)     0           sq_dims_5[0][0]
#                                                                  crop_layer_5[0][0]
# __________________________________________________________________________________________________
# Up_Conv_5 (Conv1D)              (None, 261, 168)     302568      concatenate_5[0][0]
# __________________________________________________________________________________________________
# UC_Act_5 (LeakyReLU)            (None, 261, 168)     0           Up_Conv_5[0][0]
# __________________________________________________________________________________________________
# exp_dims_6 (Lambda)             (None, 1, 261, 168)  0           UC_Act_5[0][0]
# __________________________________________________________________________________________________
# IntPol_6 (InterpolationLayer)   (None, 1, 521, 168)  168         exp_dims_6[0][0]
# __________________________________________________________________________________________________
# sq_dims_6 (Lambda)              (None, 521, 168)     0           IntPol_6[0][0]
# __________________________________________________________________________________________________
# crop_layer_6 (CropLayer)        (None, 521, 144)     0           DC_Act_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 521, 312)     0           sq_dims_6[0][0]
#                                                                  crop_layer_6[0][0]
# __________________________________________________________________________________________________
# Up_Conv_6 (Conv1D)              (None, 517, 144)     224784      concatenate_6[0][0]
# __________________________________________________________________________________________________
# UC_Act_6 (LeakyReLU)            (None, 517, 144)     0           Up_Conv_6[0][0]
# __________________________________________________________________________________________________
# exp_dims_7 (Lambda)             (None, 1, 517, 144)  0           UC_Act_6[0][0]
# __________________________________________________________________________________________________
# IntPol_7 (InterpolationLayer)   (None, 1, 1033, 144) 144         exp_dims_7[0][0]
# __________________________________________________________________________________________________
# sq_dims_7 (Lambda)              (None, 1033, 144)    0           IntPol_7[0][0]
# __________________________________________________________________________________________________
# crop_layer_7 (CropLayer)        (None, 1033, 120)    0           DC_Act_4[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1033, 264)    0           sq_dims_7[0][0]
#                                                                  crop_layer_7[0][0]
# __________________________________________________________________________________________________
# Up_Conv_7 (Conv1D)              (None, 1029, 120)    158520      concatenate_7[0][0]
# __________________________________________________________________________________________________
# UC_Act_7 (LeakyReLU)            (None, 1029, 120)    0           Up_Conv_7[0][0]
# __________________________________________________________________________________________________
# exp_dims_8 (Lambda)             (None, 1, 1029, 120) 0           UC_Act_7[0][0]
# __________________________________________________________________________________________________
# IntPol_8 (InterpolationLayer)   (None, 1, 2057, 120) 120         exp_dims_8[0][0]
# __________________________________________________________________________________________________
# sq_dims_8 (Lambda)              (None, 2057, 120)    0           IntPol_8[0][0]
# __________________________________________________________________________________________________
# crop_layer_8 (CropLayer)        (None, 2057, 96)     0           DC_Act_3[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 2057, 216)    0           sq_dims_8[0][0]
#                                                                  crop_layer_8[0][0]
# __________________________________________________________________________________________________
# Up_Conv_8 (Conv1D)              (None, 2053, 96)     103776      concatenate_8[0][0]
# __________________________________________________________________________________________________
# UC_Act_8 (LeakyReLU)            (None, 2053, 96)     0           Up_Conv_8[0][0]
# __________________________________________________________________________________________________
# exp_dims_9 (Lambda)             (None, 1, 2053, 96)  0           UC_Act_8[0][0]
# __________________________________________________________________________________________________
# IntPol_9 (InterpolationLayer)   (None, 1, 4105, 96)  96          exp_dims_9[0][0]
# __________________________________________________________________________________________________
# sq_dims_9 (Lambda)              (None, 4105, 96)     0           IntPol_9[0][0]
# __________________________________________________________________________________________________
# crop_layer_9 (CropLayer)        (None, 4105, 72)     0           DC_Act_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 4105, 168)    0           sq_dims_9[0][0]
#                                                                  crop_layer_9[0][0]
# __________________________________________________________________________________________________
# Up_Conv_9 (Conv1D)              (None, 4101, 72)     60552       concatenate_9[0][0]
# __________________________________________________________________________________________________
# UC_Act_9 (LeakyReLU)            (None, 4101, 72)     0           Up_Conv_9[0][0]
# __________________________________________________________________________________________________
# exp_dims_10 (Lambda)            (None, 1, 4101, 72)  0           UC_Act_9[0][0]
# __________________________________________________________________________________________________
# IntPol_10 (InterpolationLayer)  (None, 1, 8201, 72)  72          exp_dims_10[0][0]
# __________________________________________________________________________________________________
# sq_dims_10 (Lambda)             (None, 8201, 72)     0           IntPol_10[0][0]
# __________________________________________________________________________________________________
# crop_layer_10 (CropLayer)       (None, 8201, 48)     0           DC_Act_1[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 8201, 120)    0           sq_dims_10[0][0]
#                                                                  crop_layer_10[0][0]
# __________________________________________________________________________________________________
# Up_Conv_10 (Conv1D)             (None, 8197, 48)     28848       concatenate_10[0][0]
# __________________________________________________________________________________________________
# UC_Act_10 (LeakyReLU)           (None, 8197, 48)     0           Up_Conv_10[0][0]
# __________________________________________________________________________________________________
# exp_dims_11 (Lambda)            (None, 1, 8197, 48)  0           UC_Act_10[0][0]
# __________________________________________________________________________________________________
# IntPol_11 (InterpolationLayer)  (None, 1, 16393, 48) 48          exp_dims_11[0][0]
# __________________________________________________________________________________________________
# sq_dims_11 (Lambda)             (None, 16393, 48)    0           IntPol_11[0][0]
# __________________________________________________________________________________________________
# crop_layer_11 (CropLayer)       (None, 16393, 24)    0           DC_Act_0[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 16393, 72)    0           sq_dims_11[0][0]
#                                                                  crop_layer_11[0][0]
# __________________________________________________________________________________________________
# Up_Conv_11 (Conv1D)             (None, 16389, 24)    8664        concatenate_11[0][0]
# __________________________________________________________________________________________________
# UC_Act_11 (LeakyReLU)           (None, 16389, 24)    0           Up_Conv_11[0][0]
# __________________________________________________________________________________________________
# crop_layer_12 (CropLayer)       (None, 16389, 1)     0           raw_input[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 16389, 25)    0           UC_Act_11[0][0]
#                                                                  crop_layer_12[0][0]
# __________________________________________________________________________________________________
# audio_clip_0 (AudioClipLayer)   (None, 16389, 25)    0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# crop_layer_13 (CropLayer)       (None, 16389, 1)     0           raw_input[0][0]
# __________________________________________________________________________________________________
# diff_out (DiffOutputLayer)      {'bass': (None, 1638 26          audio_clip_0[0][0]
#                                                                  crop_layer_13[0][0]
# ==================================================================================================
# Total params: 10,265,162
# Trainable params: 10,265,162
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
o
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-aa0a18d9cd83> in <module>()
# ----> 1 o
#
# NameError: name 'o' is not defined

# %%
a = np.array((5,8, 9, 11, None))

# %%
a
# Out:
# array([5, 8, 9, 11, None], dtype=object)

# %%
tf.keras.layers.Lambda(lambda x: x[:,::2,:])(X)
